# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders and OS (Need)</span></div>

# %% [markdown]
# ## 1 Important concepts

# %% [markdown]
# ### 1.1 Path

# %% [markdown]
# ### 1.2 More about relative paths

# %% [markdown]
# ### 1.3 Path separator

# %%
# Your code here

# %% [markdown]
# ### Text files vs Binary files

# %%
# Your code here

# %% [markdown]
# ### Extentions

# %%
# Your code here

# %% [markdown]
# ### 1.4 Opening and closing files

# %%
with open('spectrum-01.txt', 'r') as file:
    file_content = file.read()

print(file_content)
# Out:
# Light Intensity, Ch A vs Actual Angular Position, Run #4
# Actual Angular Position (  )	Light Intensity, Ch A ( % max )
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.3
# 0.000	-0.2
# 0.000	-0.2
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.004	-0.1
# 0.010	-0.2
# 0.018	-0.2
# 0.024	-0.3
# 0.029	-0.3
# 0.033	-0.3
# 0.036	-0.2
# 0.039	-0.1
# 0.043	-0.1
# 0.047	-0.1
# 0.053	-0.1
# 0.060	-0.1
# 0.066	-0.1
# 0.069	-0.1
# 0.073	-0.1
# 0.076	-0.1
# 0.079	-0.1
# 0.081	-0.1
# 0.082	-0.1
# 0.083	-0.2
# 0.083	-0.2
# 0.086	-0.2
# 0.090	-0.2
# 0.095	-0.2
# 0.100	-0.3
# 0.103	-0.3
# 0.104	-0.2
# 0.105	-0.3
# 0.107	-0.2
# 0.110	-0.2
# 0.115	-0.1
# 0.122	-0.2
# 0.128	-0.1
# 0.134	-0.2
# 0.139	-0.1
# 0.144	-0.2
# 0.150	-0.2
# 0.157	-0.2
# 0.164	-0.2
# 0.170	-0.3
# 0.175	-0.3
# 0.180	-0.2
# 0.185	-0.2
# 0.191	-0.1
# 0.195	-0.1
# ...

# %%
with open('crystal.txt', 'r') as file:
    file_contents = file.read()

print(file_contents)
# Out:
# O(1)-C(7) 	1.2291(18)
# N(1)-C(6) 	1.335(2)
# N(1)-C(5) 	1.3814(18)
# N(1)-C(8) 	1.4730(19)
# N(2)-C(6) 	1.3439(18)
# N(2)-C(4) 	1.375(2)
# N(2)-C(3) 	1.4768(19)
# N(3)-C(7) 	1.3398(19)
# N(3)-C(9) 	1.4702(19)
# N(3)-C(1) 	1.4754(19)
# N(4)-C(14) 	1.3335(19)
# N(4)-C(12) 	1.383(2)
# N(4)-C(11) 	1.4723(19)
# N(5)-C(14) 	1.3350(19)
# N(5)-C(13) 	1.3749(19)
# N(5)-C(15) 	1.4661(18)
# C(1)-C(2) 	1.530(2)
# C(1)-H(1A) 	0.9900
# C(1)-H(1B) 	0.9900
# C(2)-C(3) 	1.533(2)
# C(2)-H(2A) 	0.9900
# C(2)-H(2B) 	0.9900
# C(3)-H(3A) 	0.9900
# C(3)-H(3B) 	0.9900
# C(4)-C(5) 	1.362(2)
# C(4)-H(4) 	0.9500
# C(5)-H(5) 	0.9500
# C(6)-C(7) 	1.496(2)
# C(8)-H(8A) 	0.9800
# C(8)-H(8B) 	0.9800
# C(8)-H(8C) 	0.9800
# C(9)-C(10) 	1.529(2)
# C(9)-H(9A) 	0.9900
# C(9)-H(9B) 	0.9900
# C(10)-C(11) 	1.525(2)
# C(10)-H(10A) 	0.9900
# C(10)-H(10B) 	0.9900
# C(11)-H(11A) 	0.9900
# C(11)-H(11B) 	0.9900
# C(12)-C(13) 	1.363(2)
# C(12)-H(12) 	0.9500
# C(13)-H(13) 	0.9500
# C(14)-H(14) 	0.9500
# C(15)-H(15A) 	0.9800
# ...

# %%
text = 'Far out in the uncharted backwaters of the unfashionable end of the western spiral arm of the Galaxy lies a small unregarded yellow sun.\nOrbiting this at a distance of roughly ninety-two million miles is an utterly insignificant little blue green planet whose ape-descended life forms are so amazingly primitive that they still think digital watches are a pretty neat idea.'
with open('my-text-once.txt', 'w') as file:
    file.write(text)

# %%
with open('my-text-lines.txt', 'w') as file:
    for line in text.splitlines():
        file.writelines(line)

# %% [markdown]
# ## 2 Playing with the OS

# %% [markdown]
# ### 2.1 Some packages

# %%
import os
import glob
import shutil

# %% [markdown]
# ### 2.2 OS safe paths

# %%
path = os.path.join('.', 'all-data', 'sg-data', 'data-01.txt')
print(path)
# Out:
# .\all-data\sg-data\data-01.txt

# %% [markdown]
# ### 2.3 Creating folders

# %%
os.mkdir('people')

for person in ['Jonh', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    print(f'Creating {path}')
    os.mkdir(path)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 os.mkdir('people')
#       3 for person in ['Jonh', 'Paul', 'Ringo']:
#       4     path = os.path.join('people', person)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'people'

# %% [markdown]
# ### 2.4 Checking for existence

# %%
for person in ['Jonh', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    try:
        os.mkdir(path)
        print(f'Creating {path}')
    except FileExistsError:
        print(f'{path} already exists; skipping creation.')
# Out:
# people\Jonh already exists; skipping creation.
# people\Paul already exists; skipping creation.
# people\Ringo already exists; skipping creation.

# %%
for person in ['Jonh', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    if os.path.exists(path):
        print(f'{path} already exists; skipping creation.')
    else:
        os.mkdir(path)
        print(f'Creating {path}')
# Out:
# people\Jonh already exists; skipping creation.
# people\Paul already exists; skipping creation.
# people\Ringo already exists; skipping creation.

# %% [markdown]
# ### 2.5 Copying files

# %%
for person in ['Jonh', 'Paul', 'Ringo']:
    path_to_destination = os.path.join('people', person)
    shutil.copy('sp2273_logo.png', path_to_destination)
    print(f'Copied file to {path_to_destination}')
# Out:
# Copied file to people\Jonh
# Copied file to people\Paul
# Copied file to people\Ringo

# %%
for person in ['Jonh', 'Paul', 'Ringo']:
    # Create folder 'imgs'
    path_to_imgs = os.path.join('people', person, 'imgs')
    if not os.path.exists(path_to_imgs):
        os.mkdir(path_to_imgs)

    # Move logo file
    current_path_of_logo = os.path.join('people', person, 'sp2273_logo.png')
    new_path_of_logo = os.path.join('people', person, 'imgs', 'sp2273_logo.png')

    shutil.move(current_path_of_logo, new_path_of_logo)
    print(f'Moved logo to {new_path_of_logo}')
# Out:
# Moved logo to people\Jonh\imgs\sp2273_logo.png
# Moved logo to people\Paul\imgs\sp2273_logo.png
# Moved logo to people\Ringo\imgs\sp2273_logo.png

# %% [markdown]
# ### 2.6 Listing files

# %%
glob.glob('*')
# Out:
# ['crystal.txt',
#  'files,_folders_and_os_(need).ipynb',
#  'my-text-lines.txt',
#  'my-text-once.txt',
#  'people',
#  'sp2273_logo.png',
#  'spectrum-01.txt']

# %%
glob.glob('peo*')
# Out:
# ['people']

# %%
glob.glob('cry*')
# Out:
# ['crystal.txt']

# %%
glob.glob('peo*/*')
# Out:
# ['people\\Jonh', 'people\\Paul', 'people\\Ringo']

# %%
glob.glob('people/**', recursive=True)
# Out:
# ['people\\',
#  'people\\Jonh',
#  'people\\Jonh\\imgs',
#  'people\\Jonh\\imgs\\sp2273_logo.png',
#  'people\\Paul',
#  'people\\Paul\\imgs',
#  'people\\Paul\\imgs\\sp2273_logo.png',
#  'people\\Ringo',
#  'people\\Ringo\\imgs',
#  'people\\Ringo\\imgs\\sp2273_logo.png']

# %%
glob.glob('people/**/*.png', recursive=True)
# Out:
# ['people\\Jonh\\imgs\\sp2273_logo.png',
#  'people\\Paul\\imgs\\sp2273_logo.png',
#  'people\\Ringo\\imgs\\sp2273_logo.png']

# %% [markdown]
# ### 2.7 Moving about

# %%
os.getcwd()
# Out:
# 'C:\\Users\\IGNATIUS\\OneDrive\\Documents\\GitHub\\learning-portfolio-Ignatius-Choong\\files, folders and os'

# %%
os.chdir('people/Ringo')

# %% [markdown]
# ### 2.8 Extracting Info

# %%
path = 'people/Ringo/imgs/sp2273_logo.png'
filename = path.split(os.path.sep)[-1]
extension = filename.split('.')[-1]
print(filename, extension)
# Out:
# people/Ringo/imgs/sp2273_logo.png png

# %%
path = 'people/Ringo/imgs/sp2273_logo.png'

# %%
os.path.split(path)      # Split filename from the rest
# Out:
# ('people/Ringo/imgs', 'sp2273_logo.png')

# %%
os.path.splitext(path)   # Split extension
# Out:
# ('people/Ringo/imgs/sp2273_logo', '.png')

# %%
os.path.dirname(path)    # Show the directory
# Out:
# 'people/Ringo/imgs'

# %% [markdown]
# ### 2.9 Deleting stuff

# %%
import os
import shutil
os.getcwd()
# os.chdir('..')
# os.remove('Ringo/imgs/sp2273_logo.png')
# Out:
# 'C:\\Users\\IGNATIUS\\OneDrive\\Documents\\GitHub\\learning-portfolio-Ignatius-Choong\\files, folders and os\\people'

# %%
os.rmdir('Ringo')

# %%
shutil.rmtree('Ringo')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 shutil.rmtree('Ringo')
#
# File ~\miniconda3\lib\shutil.py:749, in rmtree(path, ignore_errors, onerror)
#     747     # can't continue even if onerror hook returns
#     748     return
# --> 749 return _rmtree_unsafe(path, onerror)
#
# File ~\miniconda3\lib\shutil.py:600, in _rmtree_unsafe(path, onerror)
#     598         entries = list(scandir_it)
#     599 except OSError:
# --> 600     onerror(os.scandir, path, sys.exc_info())
#     601     entries = []
#     602 for entry in entries:
#
# File ~\miniconda3\lib\shutil.py:597, in _rmtree_unsafe(path, onerror)
#     595 def _rmtree_unsafe(path, onerror):
#     596     try:
# --> 597         with os.scandir(path) as scandir_it:
#     598             entries = list(scandir_it)
#     599     except OSError:
#
# ...

# %% [markdown]
# ## Exercise 7 :  The OS is my oyster

# %%
os.getcwd()
# Out:
# 'C:\\Users\\IGNATIUS\\OneDrive\\Documents\\GitHub\\learning-portfolio-Ignatius-Choong\\files, folders and os'

# %%
 if os.path.exists("python_today"):
        print('python_today already exists; skipping creation.')
else:
        os.mkdir("python_today")

os.chdir('python_today')
os.getcwd()
# Out:
# python_today already exists; skipping creation.
# 'C:\\Users\\IGNATIUS\\OneDrive\\Documents\\GitHub\\learning-portfolio-Ignatius-Choong\\files, folders and os\\python_today'

# %%
import os
fixed = "new_directory_"
for i in [i for i in range(1, 51)]:
    index = str(i)
    if i < 10:
        index = "0" + str(i)
    os.mkdir(fixed + index)
    
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'crystal.txt',
#  'files,_folders_and_os_(need).ipynb',
#  'my-text-lines.txt',
#  'my-text-once.txt',
#  'new_directory_01',
#  'new_directory_02',
#  'new_directory_03',
#  'new_directory_04',
#  'new_directory_05',
#  'new_directory_06',
#  'new_directory_07',
#  'new_directory_08',
#  'new_directory_09',
#  'new_directory_10',
#  'new_directory_11',
#  'new_directory_12',
#  'new_directory_13',
#  'new_directory_14',
#  'new_directory_15',
#  'new_directory_16',
#  'new_directory_17',
#  'new_directory_18',
#  'new_directory_19',
#  'new_directory_20',
#  'new_directory_21',
#  'new_directory_22',
#  'new_directory_23',
#  'new_directory_24',
#  'new_directory_25',
#  'new_directory_26',
#  'new_directory_27',
#  'new_directory_28',
#  'new_directory_29',
#  'new_directory_30',
#  'new_directory_31',
#  'new_directory_32',
#  'new_directory_33',
#  'new_directory_34',
#  'new_directory_35',
#  'new_directory_36',
#  'new_directory_37',
# ...

# %%
fixed = "new_directory_"
for i in [i for i in range(1, 51)]:
    index = str(i)
    if i%2 != 0 :
        if i < 10:
            index = "0" + str(i)
        os.rmdir(fixed + index)

os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'crystal.txt',
#  'files,_folders_and_os_(need).ipynb',
#  'my-text-lines.txt',
#  'my-text-once.txt',
#  'new_directory_02',
#  'new_directory_04',
#  'new_directory_06',
#  'new_directory_08',
#  'new_directory_10',
#  'new_directory_12',
#  'new_directory_14',
#  'new_directory_16',
#  'new_directory_18',
#  'new_directory_20',
#  'new_directory_22',
#  'new_directory_24',
#  'new_directory_26',
#  'new_directory_28',
#  'new_directory_30',
#  'new_directory_32',
#  'new_directory_34',
#  'new_directory_36',
#  'new_directory_38',
#  'new_directory_40',
#  'new_directory_42',
#  'new_directory_44',
#  'new_directory_46',
#  'new_directory_48',
#  'new_directory_50',
#  'people',
#  'python_today',
#  'sp2273_logo.png',
#  'spectrum-01.txt']

# %%
fixed = "new_directory_"
new = "haha"
for i in [i for i in range(1, 51)]:
    index = str(i)
    if i < 10:
        index = "0" + str(i)
    if i%5 == 0 :
        if os.path.exists(fixed + index):
            os.rename(fixed + index,new + index)
        else:
            print(f"file {i} not found")

os.listdir()
# Out:
# file 5 not found
# file 15 not found
# file 25 not found
# file 35 not found
# file 45 not found
# ['.ipynb_checkpoints',
#  'crystal.txt',
#  'files,_folders_and_os_(need).ipynb',
#  'haha10',
#  'haha20',
#  'haha30',
#  'haha40',
#  'haha50',
#  'my-text-lines.txt',
#  'my-text-once.txt',
#  'new_directory_02',
#  'new_directory_04',
#  'new_directory_06',
#  'new_directory_08',
#  'new_directory_12',
#  'new_directory_14',
#  'new_directory_16',
#  'new_directory_18',
#  'new_directory_22',
#  'new_directory_24',
#  'new_directory_26',
#  'new_directory_28',
#  'new_directory_32',
#  'new_directory_34',
#  'new_directory_36',
#  'new_directory_38',
#  'new_directory_42',
#  'new_directory_44',
#  'new_directory_46',
#  'new_directory_48',
#  'people',
#  'python_today',
#  'sp2273_logo.png',
#  'spectrum-01.txt']

# %%
import glob
for file in glob.glob('haha*'):
        shutil.copy('sp2273_logo.png', file)
    
# os.listdir()
# os.chdir('files, folders and os')

# os.getcwd()

glob.glob('haha*')
# Out:
# ['haha10', 'haha20', 'haha30', 'haha40', 'haha50']

# %% [markdown]
# ## Exercise 8 :  Tidying a collaboration

# %%
raw_date = 'oct-08_singapore.txt'

month_dictionary = {
                    'jan': '01', 'feb': '02', 'mar': '03',
                    'apr': '04', 'may': '05', 'jun': '06',
                    'jul': '07', 'aug': '08', 'sep': '09',
                    'oct': '10', 'nov': '11', 'dec': '12'
                    }

month = raw_date[0:3]
#print(month_dictionary[month])
print(f'{month_dictionary[month]}{raw_date[3:6]}-{raw_date[7:len(raw_date)]}')
# Out:
# 10-08-singapore.txt

# %%
month_dictionary = {
                    'jan': '01', 'feb': '02', 'mar': '03',
                    'apr': '04', 'may': '05', 'jun': '06',
                    'jul': '07', 'aug': '08', 'sep': '09',
                    'oct': '10', 'nov': '11', 'dec': '12'
                    }



def rename_my_file(old_file_name):
    return f'{month_dictionary[old_file_name[0:3]]}{old_file_name[3:6]}-{old_file_name[7:len(old_file_name)]}'

rename_my_file('jan-09_singapore.txt')
# Out:
# '01-09-singapore.txt'

# %%
month_dictionary.keys()
# Out:
# dict_keys(['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec'])

# %%
def rename_my_file(old_file_name):
    if old_file_name[0:3] in month_dictionary.keys():
        return f'{month_dictionary[old_file_name[0:3]]}{old_file_name[3:6]}-{old_file_name[7:len(old_file_name)]}'
    else:
        return old_file_name
raw_data = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt', '01-01_tokyo.txt']

for data in raw_data:
    #print(data)
    rename_my_file(data)
    print(f'{data} ----> {rename_my_file(data)}')
# Out:
# oct-08_singapore.txt ----> 10-08-singapore.txt
# jul-10_cairo.txt ----> 07-10-cairo.txt
# may-15_dhaka.txt ----> 05-15-dhaka.txt
# may-13_cairo.txt ----> 05-13-cairo.txt
# oct-21_cairo.txt ----> 10-21-cairo.txt
# jan-10_singapore.txt ----> 01-10-singapore.txt
# jun-20_tokyo.txt ----> 06-20-tokyo.txt
# aug-06_jakarta.txt ----> 08-06-jakarta.txt
# dec-21_karachi.txt ----> 12-21-karachi.txt
# jan-01_tokyo.txt ----> 01-01-tokyo.txt
# 01-01_tokyo.txt ----> 01-01_tokyo.txt

# %%
import os
import glob
#glob.glob('os*')
#os.chdir('os-collaboration-exercise-data')
os.getcwd()


raw_data = glob.glob('*.txt')
for data in raw_data:
    #print(data)
    new_name = rename_my_file(data)
    os.rename(data,new_name)  
    #print(f'{data} ----> {rename_my_file(data)}')

# %%
#os.chdir('..')
os.getcwd()
cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

for city in cities:
     os.mkdir(city)
    
#os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Cairo',
#  'crystal.txt',
#  'Dhaka',
#  'files,_folders_and_os_(need).ipynb',
#  'haha10',
#  'haha20',
#  'haha30',
#  'haha40',
#  'haha50',
#  'Jakarta',
#  'Karachi',
#  'Manila',
#  'Melbourne',
#  'my-text-lines.txt',
#  'my-text-once.txt',
#  'new_directory_02',
#  'new_directory_04',
#  'new_directory_06',
#  'new_directory_08',
#  'new_directory_12',
#  'new_directory_14',
#  'new_directory_16',
#  'new_directory_18',
#  'new_directory_22',
#  'new_directory_24',
#  'new_directory_26',
#  'new_directory_28',
#  'new_directory_32',
#  'new_directory_34',
#  'new_directory_36',
#  'new_directory_38',
#  'new_directory_42',
#  'new_directory_44',
#  'new_directory_46',
#  'new_directory_48',
#  'os-collaboration-exercise-data',
#  'Osaka',
#  'people',
#  'python_today',
#  'Shanghai',
#  'Singapore',
#  'sp2273_logo.png',
#  'spectrum-01.txt',
#  'Tokyo']

# %%
#os.chdir('os-collaboration-exercise-data')
import shutil
cairo_txt = glob.glob('*cairo.txt')
for txt in cairo_txt:
        shutil.copy(txt, 'Cairo')
#os.listdir('Cairo')
# Out:
# ['01-02-cairo.txt',
#  '01-03-cairo.txt',
#  '01-04-cairo.txt',
#  '01-05-cairo.txt',
#  '01-07-cairo.txt',
#  '01-08-cairo.txt',
#  '01-09-cairo.txt',
#  '01-11-cairo.txt',
#  '01-12-cairo.txt',
#  '01-13-cairo.txt',
#  '01-15-cairo.txt',
#  '01-16-cairo.txt',
#  '01-19-cairo.txt',
#  '01-20-cairo.txt',
#  '01-21-cairo.txt',
#  '01-23-cairo.txt',
#  '01-27-cairo.txt',
#  '01-30-cairo.txt',
#  '02-10-cairo.txt',
#  '02-17-cairo.txt',
#  '02-20-cairo.txt',
#  '02-22-cairo.txt',
#  '02-25-cairo.txt',
#  '02-26-cairo.txt',
#  '03-05-cairo.txt',
#  '03-06-cairo.txt',
#  '03-12-cairo.txt',
#  '03-14-cairo.txt',
#  '03-19-cairo.txt',
#  '03-24-cairo.txt',
#  '04-02-cairo.txt',
#  '04-06-cairo.txt',
#  '04-07-cairo.txt',
#  '04-10-cairo.txt',
#  '04-12-cairo.txt',
#  '04-13-cairo.txt',
#  '04-14-cairo.txt',
#  '04-15-cairo.txt',
#  '04-17-cairo.txt',
#  '04-20-cairo.txt',
#  '04-21-cairo.txt',
#  '04-22-cairo.txt',
#  '04-23-cairo.txt',
#  '04-24-cairo.txt',
#  '05-01-cairo.txt',
# ...

# %%
#os.chdir('os-collaboration-exercise-data')
dhaka_txt = glob.glob('*dhaka.txt')
for txt in dhaka_txt:
        shutil.copy(txt, 'Dhaka')
os.listdir('Dhaka')
# Out:
# ['01-15-dhaka.txt',
#  '02-01-dhaka.txt',
#  '02-04-dhaka.txt',
#  '02-08-dhaka.txt',
#  '02-12-dhaka.txt',
#  '02-14-dhaka.txt',
#  '02-20-dhaka.txt',
#  '02-22-dhaka.txt',
#  '03-16-dhaka.txt',
#  '04-19-dhaka.txt',
#  '04-20-dhaka.txt',
#  '04-23-dhaka.txt',
#  '05-01-dhaka.txt',
#  '05-02-dhaka.txt',
#  '05-04-dhaka.txt',
#  '05-05-dhaka.txt',
#  '05-10-dhaka.txt',
#  '05-11-dhaka.txt',
#  '05-14-dhaka.txt',
#  '05-15-dhaka.txt',
#  '05-17-dhaka.txt',
#  '05-21-dhaka.txt',
#  '05-24-dhaka.txt',
#  '05-26-dhaka.txt',
#  '05-27-dhaka.txt',
#  '05-28-dhaka.txt',
#  '05-29-dhaka.txt',
#  '05-30-dhaka.txt',
#  '06-02-dhaka.txt',
#  '06-04-dhaka.txt',
#  '06-05-dhaka.txt',
#  '06-07-dhaka.txt',
#  '06-09-dhaka.txt',
#  '06-11-dhaka.txt',
#  '06-12-dhaka.txt',
#  '06-17-dhaka.txt',
#  '06-18-dhaka.txt',
#  '06-19-dhaka.txt',
#  '06-20-dhaka.txt',
#  '06-21-dhaka.txt',
#  '06-22-dhaka.txt',
#  '06-23-dhaka.txt',
#  '06-24-dhaka.txt',
#  '06-25-dhaka.txt',
#  '06-26-dhaka.txt',
# ...

# %%
jarkata_txt = glob.glob('*jakarta.txt')
for txt in jarkata_txt:
        shutil.copy(txt, 'Jakarta')
os.listdir('Jakarta')
# Out:
# ['01-03-jakarta.txt',
#  '01-04-jakarta.txt',
#  '01-06-jakarta.txt',
#  '01-10-jakarta.txt',
#  '01-12-jakarta.txt',
#  '01-13-jakarta.txt',
#  '01-16-jakarta.txt',
#  '01-19-jakarta.txt',
#  '01-23-jakarta.txt',
#  '01-24-jakarta.txt',
#  '01-26-jakarta.txt',
#  '01-30-jakarta.txt',
#  '02-02-jakarta.txt',
#  '02-04-jakarta.txt',
#  '02-06-jakarta.txt',
#  '02-09-jakarta.txt',
#  '02-10-jakarta.txt',
#  '02-14-jakarta.txt',
#  '02-15-jakarta.txt',
#  '02-20-jakarta.txt',
#  '02-21-jakarta.txt',
#  '02-26-jakarta.txt',
#  '02-27-jakarta.txt',
#  '03-04-jakarta.txt',
#  '03-09-jakarta.txt',
#  '03-11-jakarta.txt',
#  '03-15-jakarta.txt',
#  '03-17-jakarta.txt',
#  '03-18-jakarta.txt',
#  '03-20-jakarta.txt',
#  '03-23-jakarta.txt',
#  '03-25-jakarta.txt',
#  '03-30-jakarta.txt',
#  '04-02-jakarta.txt',
#  '04-06-jakarta.txt',
#  '04-13-jakarta.txt',
#  '04-15-jakarta.txt',
#  '04-16-jakarta.txt',
#  '04-20-jakarta.txt',
#  '04-21-jakarta.txt',
#  '04-23-jakarta.txt',
# ...

# %%
k_txt = glob.glob('*karachi.txt')
for txt in k_txt:
        shutil.copy(txt, 'Karachi')
os.listdir('Karachi')
# Out:
# ['01-02-karachi.txt',
#  '01-03-karachi.txt',
#  '01-04-karachi.txt',
#  '01-06-karachi.txt',
#  '01-09-karachi.txt',
#  '01-10-karachi.txt',
#  '01-12-karachi.txt',
#  '01-14-karachi.txt',
#  '01-17-karachi.txt',
#  '01-18-karachi.txt',
#  '01-19-karachi.txt',
#  '01-20-karachi.txt',
#  '01-21-karachi.txt',
#  '01-22-karachi.txt',
#  '01-24-karachi.txt',
#  '01-25-karachi.txt',
#  '01-26-karachi.txt',
#  '01-28-karachi.txt',
#  '01-30-karachi.txt',
#  '02-06-karachi.txt',
#  '02-08-karachi.txt',
#  '02-17-karachi.txt',
#  '03-06-karachi.txt',
#  '04-02-karachi.txt',
#  '04-05-karachi.txt',
#  '04-06-karachi.txt',
#  '04-12-karachi.txt',
#  '04-16-karachi.txt',
#  '04-20-karachi.txt',
#  '04-26-karachi.txt',
#  '04-27-karachi.txt',
#  '05-03-karachi.txt',
#  '05-05-karachi.txt',
#  '05-06-karachi.txt',
#  '05-10-karachi.txt',
#  '05-17-karachi.txt',
#  '05-18-karachi.txt',
#  '05-20-karachi.txt',
#  '05-23-karachi.txt',
#  '05-26-karachi.txt',
#  '05-27-karachi.txt',
# ...

# %%
m_txt = glob.glob('*manila.txt')
for txt in m_txt:
        shutil.copy(txt, 'Manila')
os.listdir('Manila')
# Out:
# ['01-01-manila.txt',
#  '01-02-manila.txt',
#  '01-04-manila.txt',
#  '01-08-manila.txt',
#  '01-09-manila.txt',
#  '01-11-manila.txt',
#  '01-14-manila.txt',
#  '01-15-manila.txt',
#  '01-18-manila.txt',
#  '01-19-manila.txt',
#  '01-23-manila.txt',
#  '01-24-manila.txt',
#  '01-25-manila.txt',
#  '01-26-manila.txt',
#  '01-30-manila.txt',
#  '02-01-manila.txt',
#  '02-03-manila.txt',
#  '02-04-manila.txt',
#  '02-05-manila.txt',
#  '02-06-manila.txt',
#  '02-07-manila.txt',
#  '02-08-manila.txt',
#  '02-09-manila.txt',
#  '02-10-manila.txt',
#  '02-12-manila.txt',
#  '02-13-manila.txt',
#  '02-15-manila.txt',
#  '02-18-manila.txt',
#  '02-21-manila.txt',
#  '02-22-manila.txt',
#  '02-23-manila.txt',
#  '02-24-manila.txt',
#  '02-26-manila.txt',
#  '02-27-manila.txt',
#  '03-02-manila.txt',
#  '03-08-manila.txt',
#  '03-09-manila.txt',
#  '03-10-manila.txt',
#  '03-12-manila.txt',
#  '03-13-manila.txt',
#  '03-16-manila.txt',
#  '03-17-manila.txt',
#  '03-18-manila.txt',
# ...

# %%
mel_txt = glob.glob('*melbourne.txt')
for txt in mel_txt:
        shutil.copy(txt, 'Melbourne')
os.listdir('Melbourne')
# Out:
# ['01-05-melbourne.txt',
#  '01-06-melbourne.txt',
#  '01-09-melbourne.txt',
#  '01-11-melbourne.txt',
#  '01-12-melbourne.txt',
#  '01-13-melbourne.txt',
#  '01-16-melbourne.txt',
#  '01-18-melbourne.txt',
#  '01-19-melbourne.txt',
#  '01-21-melbourne.txt',
#  '01-22-melbourne.txt',
#  '01-24-melbourne.txt',
#  '01-25-melbourne.txt',
#  '01-27-melbourne.txt',
#  '01-29-melbourne.txt',
#  '02-13-melbourne.txt',
#  '02-16-melbourne.txt',
#  '03-07-melbourne.txt',
#  '04-01-melbourne.txt',
#  '04-04-melbourne.txt',
#  '04-05-melbourne.txt',
#  '04-07-melbourne.txt',
#  '04-10-melbourne.txt',
#  '04-11-melbourne.txt',
#  '04-12-melbourne.txt',
#  '04-13-melbourne.txt',
#  '04-14-melbourne.txt',
#  '04-15-melbourne.txt',
#  '04-16-melbourne.txt',
#  '04-19-melbourne.txt',
#  '04-21-melbourne.txt',
#  '04-24-melbourne.txt',
#  '04-27-melbourne.txt',
#  '04-29-melbourne.txt',
#  '05-02-melbourne.txt',
#  '05-03-melbourne.txt',
#  '05-04-melbourne.txt',
#  '05-05-melbourne.txt',
# ...

# %%
o_txt = glob.glob('*osaka.txt')
for txt in o_txt:
        shutil.copy(txt, 'Osaka')
os.listdir('Osaka')
# Out:
# ['01-01-osaka.txt',
#  '01-05-osaka.txt',
#  '01-08-osaka.txt',
#  '01-12-osaka.txt',
#  '01-15-osaka.txt',
#  '01-18-osaka.txt',
#  '01-19-osaka.txt',
#  '01-20-osaka.txt',
#  '01-22-osaka.txt',
#  '01-25-osaka.txt',
#  '01-27-osaka.txt',
#  '02-01-osaka.txt',
#  '02-02-osaka.txt',
#  '02-03-osaka.txt',
#  '02-04-osaka.txt',
#  '02-06-osaka.txt',
#  '02-07-osaka.txt',
#  '02-09-osaka.txt',
#  '02-10-osaka.txt',
#  '02-11-osaka.txt',
#  '02-14-osaka.txt',
#  '02-16-osaka.txt',
#  '02-19-osaka.txt',
#  '02-20-osaka.txt',
#  '02-21-osaka.txt',
#  '02-24-osaka.txt',
#  '02-26-osaka.txt',
#  '02-27-osaka.txt',
#  '03-04-osaka.txt',
#  '03-08-osaka.txt',
#  '03-10-osaka.txt',
#  '03-11-osaka.txt',
#  '03-12-osaka.txt',
#  '03-19-osaka.txt',
#  '03-22-osaka.txt',
#  '03-27-osaka.txt',
#  '03-30-osaka.txt',
#  '04-03-osaka.txt',
#  '04-07-osaka.txt',
#  '04-12-osaka.txt',
#  '04-14-osaka.txt',
#  '04-16-osaka.txt',
#  '04-18-osaka.txt',
#  '04-21-osaka.txt',
#  '04-23-osaka.txt',
# ...

# %%
shan_txt = glob.glob('*shanghai.txt')
for txt in shan_txt:
        shutil.copy(txt, 'Shanghai')
os.listdir('Shanghai')
# Out:
# ['01-03-shanghai.txt',
#  '01-10-shanghai.txt',
#  '01-22-shanghai.txt',
#  '01-26-shanghai.txt',
#  '01-29-shanghai.txt',
#  '02-01-shanghai.txt',
#  '02-05-shanghai.txt',
#  '02-11-shanghai.txt',
#  '02-12-shanghai.txt',
#  '02-13-shanghai.txt',
#  '02-15-shanghai.txt',
#  '02-16-shanghai.txt',
#  '02-17-shanghai.txt',
#  '02-18-shanghai.txt',
#  '02-23-shanghai.txt',
#  '03-14-shanghai.txt',
#  '03-16-shanghai.txt',
#  '04-01-shanghai.txt',
#  '04-02-shanghai.txt',
#  '04-04-shanghai.txt',
#  '04-05-shanghai.txt',
#  '04-08-shanghai.txt',
#  '04-10-shanghai.txt',
#  '04-11-shanghai.txt',
#  '04-12-shanghai.txt',
#  '04-13-shanghai.txt',
#  '04-16-shanghai.txt',
#  '04-17-shanghai.txt',
#  '04-18-shanghai.txt',
#  '04-19-shanghai.txt',
#  '04-21-shanghai.txt',
#  '04-23-shanghai.txt',
#  '04-27-shanghai.txt',
#  '04-29-shanghai.txt',
#  '05-01-shanghai.txt',
#  '05-03-shanghai.txt',
#  '05-06-shanghai.txt',
#  '05-14-shanghai.txt',
#  '05-18-shanghai.txt',
#  '05-26-shanghai.txt',
# ...

# %%
sin_txt = glob.glob('*singapore.txt')
for txt in sin_txt:
        shutil.copy(txt, 'Singapore')
os.listdir('Singapore')
# Out:
# ['01-15-singapore.txt',
#  '02-01-singapore.txt',
#  '02-02-singapore.txt',
#  '02-03-singapore.txt',
#  '02-04-singapore.txt',
#  '02-05-singapore.txt',
#  '02-08-singapore.txt',
#  '02-12-singapore.txt',
#  '02-13-singapore.txt',
#  '02-14-singapore.txt',
#  '02-15-singapore.txt',
#  '02-17-singapore.txt',
#  '02-19-singapore.txt',
#  '02-20-singapore.txt',
#  '02-23-singapore.txt',
#  '02-24-singapore.txt',
#  '02-27-singapore.txt',
#  '03-05-singapore.txt',
#  '04-01-singapore.txt',
#  '04-03-singapore.txt',
#  '04-04-singapore.txt',
#  '04-05-singapore.txt',
#  '04-07-singapore.txt',
#  '04-10-singapore.txt',
#  '04-12-singapore.txt',
#  '04-13-singapore.txt',
#  '04-14-singapore.txt',
#  '04-15-singapore.txt',
#  '04-19-singapore.txt',
#  '04-21-singapore.txt',
#  '04-22-singapore.txt',
#  '04-23-singapore.txt',
#  '04-25-singapore.txt',
#  '04-26-singapore.txt',
#  '05-01-singapore.txt',
#  '05-04-singapore.txt',
#  '05-06-singapore.txt',
#  '05-08-singapore.txt',
# ...

# %%
tokyo_txt = glob.glob('*tokyo.txt')
for txt in tokyo_txt:
        shutil.copy(txt, 'Tokyo')
os.listdir('Tokyo')
# Out:
# ['01-08-tokyo.txt',
#  '01-12-tokyo.txt',
#  '01-16-tokyo.txt',
#  '01-19-tokyo.txt',
#  '01-20-tokyo.txt',
#  '01-22-tokyo.txt',
#  '01-24-tokyo.txt',
#  '02-03-tokyo.txt',
#  '02-04-tokyo.txt',
#  '02-05-tokyo.txt',
#  '02-06-tokyo.txt',
#  '02-07-tokyo.txt',
#  '02-09-tokyo.txt',
#  '02-12-tokyo.txt',
#  '02-13-tokyo.txt',
#  '02-14-tokyo.txt',
#  '02-16-tokyo.txt',
#  '02-19-tokyo.txt',
#  '02-20-tokyo.txt',
#  '02-21-tokyo.txt',
#  '02-22-tokyo.txt',
#  '02-24-tokyo.txt',
#  '02-27-tokyo.txt',
#  '03-04-tokyo.txt',
#  '03-05-tokyo.txt',
#  '03-09-tokyo.txt',
#  '03-14-tokyo.txt',
#  '03-15-tokyo.txt',
#  '03-16-tokyo.txt',
#  '03-18-tokyo.txt',
#  '03-26-tokyo.txt',
#  '03-27-tokyo.txt',
#  '04-03-tokyo.txt',
#  '04-07-tokyo.txt',
#  '04-10-tokyo.txt',
#  '04-11-tokyo.txt',
#  '04-12-tokyo.txt',
#  '04-15-tokyo.txt',
#  '04-17-tokyo.txt',
#  '04-18-tokyo.txt',
#  '04-20-tokyo.txt',
#  '04-21-tokyo.txt',
#  '04-23-tokyo.txt',
#  '04-24-tokyo.txt',
#  '04-27-tokyo.txt',
# ...
